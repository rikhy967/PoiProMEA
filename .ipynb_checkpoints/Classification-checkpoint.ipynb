# %% [markdown]
# # Machine Learning Classification

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,recall_score,precision_score,roc_auc_score

from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import seaborn as sns

#hyperopt
from hyperopt import hp
from hyperopt import fmin, tpe, Trials
from hyperopt.pyll import scope
@scope.define
def intero(a):
     return int(a)

# %%
def performance_visualizer(trials_obj,n_models,choice=False,**choice_var):
    
    import pandas as pd
    
    performance = [1-t['result']['loss'] for t in trials_obj.trials]
    
    
    hyperparam= list(trials_obj.trials[0]['misc']['vals'].keys())
    
    values_dict ={}
    
    for i in hyperparam:
        
        values_dict[i]=[]
        
        for j in trials_obj.trials:
            
            if(len(j['misc']['vals'][i])==0):
                
                values_dict[i].append(np.NaN)
                
            else:
            
                values_dict[i].append(j['misc']['vals'][i][0])
                
    out = pd.DataFrame.from_dict(values_dict)
    
    out['performance'] = performance
    
    out=out.sort_values(by=['performance'])
    
    
    if choice:
        
        for i in list(choice_var.keys()):
        
            for j,_ in enumerate(choice_var[i]):
        
                out[i]=out[i].replace(j,choice_var[i][j])
    
    return out.tail(n_models)

# %%
dataset = pd.read_csv('Data after PP/Data')

# %%
dataset = dataset.drop(['Unnamed: 0'],axis=1)

# %%
dataset
# Out:
#           mu1      lam1           mu2     sigma       mu3    sigma3        w1  \
# 0    0.099999  0.010000  1.376800e-01  0.069408  0.368091  0.172628  0.286221
# 1    0.019293  0.019831  6.633874e-02  0.000100  0.100001  0.000520  1.000000
# 2    0.043575  0.029764  1.779872e-01  0.000100  0.100064  0.000260  1.000000
# 3    0.024164  0.022119  6.418069e-02  0.000100  0.100010  0.000718  1.000000
# 4    0.048184  0.030814  4.696582e-03  0.000100  0.100139  0.000218  1.000000
# ..        ...       ...           ...       ...       ...       ...       ...
# 543  0.100000  0.011880  1.038845e-01  0.058294  0.483309  0.271518  0.332834
# 544  0.018542  0.018771  1.807094e-01  0.000100  0.100000  0.000106  1.000000
# 545  0.099969  0.039687  9.343772e-02  0.040354  0.267501  0.112234  0.630343
# 546  0.056240  0.031443  1.643654e-07  0.000100  0.100001  0.000100  1.000000
# 547  0.100000  0.040000  1.008357e-01  0.044780  0.403570  0.174828  0.774085
#
#                w2            w3  n_spikes  Target
# 0    4.179009e-01  2.958779e-01    1015.0     0.0
# 1    1.192093e-07  1.421085e-14   10364.0     0.0
# 2    1.192093e-07  1.421085e-14    4589.0     0.0
# 3    1.192093e-07  1.421085e-14    8274.0     0.0
# 4    1.192093e-07  1.421085e-14    4151.0     0.0
# ..            ...           ...       ...     ...
# 543  4.549999e-01  2.121657e-01    1029.0     1.0
# 544  1.192093e-07  1.421085e-14   10784.0     1.0
# 545  2.080073e-01  1.616492e-01    1523.0     1.0
# 546  1.192093e-07  1.421085e-14    3555.0     1.0
# 547  1.422010e-01  8.371432e-02    1475.0     1.0
#
# [548 rows x 11 columns]

# %%
dataset['Target'].value_counts()
# Out:
# 0.0    317
# 1.0    231
# Name: Target, dtype: int64

# %% [markdown]
# ## Train test split

# %%
X = dataset.drop(['Target'],axis=1)
y= dataset['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25,
                                                    stratify=y,
                                                    random_state=42)

# %% [markdown]
# ## Standardization

# %%
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Model Comparison

# %%
cv = StratifiedKFold(4)

# %% [markdown]
# ## 1) Decision Tree Classifier

# %%
params = {'max_depth':np.linspace(2,10,dtype='int'),'criterion':['gini','entropy']}

clf = DecisionTreeClassifier(random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)

gs=gs.fit(X_train,y_train)

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# Best parameters set found : {'criterion': 'entropy', 'max_depth': 4}
#
# Classification report on Test set
#
# Accuracy:  0.912
# Recall:  0.931
# Precision:  0.871
# ROC AUC:  0.915

# %% [markdown]
# ## 2) Logistic Regression

# %%
params = {'C':np.logspace(-3,3,50),'penalty':['l1','l2','elasticnet']}

clf = LogisticRegression(solver='liblinear',random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)

gs=gs.fit(X_train,y_train)

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# Best parameters set found : {'C': 0.21209508879201905, 'penalty': 'l1'}
#
# Classification report on Test set
#
# Accuracy:  0.825
# Recall:  0.655
# Precision:  0.905
# ROC AUC:  0.802

# %% [markdown]
# ## 3) Support Vector Machines

# %%
params = {'C':np.logspace(-3,3,50),'kernel':['linear','rbf']}

clf = SVC(random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)

gs=gs.fit(X_train,y_train)

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# Best parameters set found : {'C': 8.286427728546842, 'kernel': 'rbf'}
#
# Classification report on Test set
#
# Accuracy:  0.927
# Recall:  0.931
# Precision:  0.9
# ROC AUC:  0.928

# %%
svm_params = gs.best_params_

# %% [markdown]
# ## 4) Random Forest

# %%
params = {'n_estimators':np.linspace(10,150,dtype='int',num=10),'max_depth':np.linspace(2,5,dtype='int'),'criterion':['gini','entropy']}

clf = RandomForestClassifier(n_jobs=-1,random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,verbose=10,n_jobs=-1)

gs=gs.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1029s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 634 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 746 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 804 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 928 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 994 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 1060 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 1130 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 1200 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 1274 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 1348 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 1426 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done 1504 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 1586 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done 1668 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done 1754 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 1840 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 1930 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 2020 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 2114 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 2208 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 2306 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done 2404 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 2506 tasks      | elapsed:   44.8s
# [Parallel(n_jobs=-1)]: Done 2608 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done 2714 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 2820 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done 2930 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 3040 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 3154 tasks      | elapsed:   56.4s
# [Parallel(n_jobs=-1)]: Done 3268 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 3386 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 3504 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 3626 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3748 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 3874 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 4000 out of 4000 | elapsed:  1.2min finished

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# Best parameters set found : {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 134}
#
# Classification report on Test set
#
# Accuracy:  0.912
# Recall:  0.914
# Precision:  0.883
# ROC AUC:  0.913

# %% [markdown]
# ## 5) Neural Net

# %%
X_train.shape
# Out:
# (411, 10)

# %%
import torch
print(torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-284f044b2a81> in <module>
# ----> 1 import torch
#       2 print(torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch'

# %%
from tensorflow import keras

model = keras.Sequential(
    [
        keras.layers.Dense(
            20, activation="relu", input_shape=(X_train.shape[1],)
        ),
        keras.layers.Dense(100, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(50, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                220
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               2100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 7,421
# Trainable params: 7,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = [
    'accuracy',
    keras.metrics.FalseNegatives(name="fn"),
    keras.metrics.FalsePositives(name="fp"),
    keras.metrics.TrueNegatives(name="tn"),
    keras.metrics.TruePositives(name="tp"),
    keras.metrics.Precision(name="precision"),
    keras.metrics.Recall(name="recall"),
]

model.compile(
    optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=metrics
)



history=model.fit(
    X_train,
    y_train,
    batch_size=10,
    epochs=200,
    validation_data=(X_test, y_test),

)
# Out:
# Epoch 1/200
# 42/42 [==============================] - 1s 22ms/step - loss: 0.5450 - accuracy: 0.7518 - fn: 63.0000 - fp: 39.0000 - tn: 199.0000 - tp: 110.0000 - precision: 0.7383 - recall: 0.6358 - val_loss: 0.4062 - val_accuracy: 0.8540 - val_fn: 12.0000 - val_fp: 8.0000 - val_tn: 71.0000 - val_tp: 46.0000 - val_precision: 0.8519 - val_recall: 0.7931
# Epoch 2/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8491 - fn: 32.0000 - fp: 30.0000 - tn: 208.0000 - tp: 141.0000 - precision: 0.8246 - recall: 0.8150 - val_loss: 0.3755 - val_accuracy: 0.8613 - val_fn: 3.0000 - val_fp: 16.0000 - val_tn: 63.0000 - val_tp: 55.0000 - val_precision: 0.7746 - val_recall: 0.9483
# Epoch 3/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.4074 - accuracy: 0.8005 - fn: 32.0000 - fp: 50.0000 - tn: 188.0000 - tp: 141.0000 - precision: 0.7382 - recall: 0.8150 - val_loss: 0.3098 - val_accuracy: 0.9124 - val_fn: 5.0000 - val_fp: 7.0000 - val_tn: 72.0000 - val_tp: 53.0000 - val_precision: 0.8833 - val_recall: 0.9138
# Epoch 4/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2949 - accuracy: 0.8808 - fn: 18.0000 - fp: 31.0000 - tn: 207.0000 - tp: 155.0000 - precision: 0.8333 - recall: 0.8960 - val_loss: 0.2548 - val_accuracy: 0.8905 - val_fn: 14.0000 - val_fp: 1.0000 - val_tn: 78.0000 - val_tp: 44.0000 - val_precision: 0.9778 - val_recall: 0.7586
# Epoch 5/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3281 - accuracy: 0.8564 - fn: 32.0000 - fp: 27.0000 - tn: 211.0000 - tp: 141.0000 - precision: 0.8393 - recall: 0.8150 - val_loss: 0.2468 - val_accuracy: 0.9197 - val_fn: 10.0000 - val_fp: 1.0000 - val_tn: 78.0000 - val_tp: 48.0000 - val_precision: 0.9796 - val_recall: 0.8276
# Epoch 6/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2802 - accuracy: 0.8759 - fn: 20.0000 - fp: 31.0000 - tn: 207.0000 - tp: 153.0000 - precision: 0.8315 - recall: 0.8844 - val_loss: 0.2072 - val_accuracy: 0.9197 - val_fn: 3.0000 - val_fp: 8.0000 - val_tn: 71.0000 - val_tp: 55.0000 - val_precision: 0.8730 - val_recall: 0.9483
# Epoch 7/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2817 - accuracy: 0.8929 - fn: 18.0000 - fp: 26.0000 - tn: 212.0000 - tp: 155.0000 - precision: 0.8564 - recall: 0.8960 - val_loss: 0.2900 - val_accuracy: 0.8759 - val_fn: 2.0000 - val_fp: 15.0000 - val_tn: 64.0000 - val_tp: 56.0000 - val_precision: 0.7887 - val_recall: 0.9655
# Epoch 8/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2703 - accuracy: 0.8783 - fn: 21.0000 - fp: 29.0000 - tn: 209.0000 - tp: 152.0000 - precision: 0.8398 - recall: 0.8786 - val_loss: 0.2441 - val_accuracy: 0.9124 - val_fn: 3.0000 - val_fp: 9.0000 - val_tn: 70.0000 - val_tp: 55.0000 - val_precision: 0.8594 - val_recall: 0.9483
# Epoch 9/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2748 - accuracy: 0.8929 - fn: 20.0000 - fp: 24.0000 - tn: 214.0000 - tp: 153.0000 - precision: 0.8644 - recall: 0.8844 - val_loss: 0.3643 - val_accuracy: 0.8102 - val_fn: 24.0000 - val_fp: 2.0000 - val_tn: 77.0000 - val_tp: 34.0000 - val_precision: 0.9444 - val_recall: 0.5862
# Epoch 10/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.8589 - fn: 28.0000 - fp: 30.0000 - tn: 208.0000 - tp: 145.0000 - precision: 0.8286 - recall: 0.8382 - val_loss: 0.2642 - val_accuracy: 0.9051 - val_fn: 8.0000 - val_fp: 5.0000 - val_tn: 74.0000 - val_tp: 50.0000 - val_precision: 0.9091 - val_recall: 0.8621
# Epoch 11/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.3081 - accuracy: 0.8783 - fn: 25.0000 - fp: 25.0000 - tn: 213.0000 - tp: 148.0000 - precision: 0.8555 - recall: 0.8555 - val_loss: 0.2284 - val_accuracy: 0.9197 - val_fn: 6.0000 - val_fp: 5.0000 - val_tn: 74.0000 - val_tp: 52.0000 - val_precision: 0.9123 - val_recall: 0.8966
# Epoch 12/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.2824 - accuracy: 0.8881 - fn: 17.0000 - fp: 29.0000 - tn: 209.0000 - tp: 156.0000 - precision: 0.8432 - recall: 0.9017 - val_loss: 0.2641 - val_accuracy: 0.9270 - val_fn: 4.0000 - val_fp: 6.0000 - val_tn: 73.0000 - val_tp: 54.0000 - val_precision: 0.9000 - val_recall: 0.9310
# Epoch 13/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2769 - accuracy: 0.8929 - fn: 21.0000 - fp: 23.0000 - tn: 215.0000 - tp: 152.0000 - precision: 0.8686 - recall: 0.8786 - val_loss: 0.1792 - val_accuracy: 0.9270 - val_fn: 4.0000 - val_fp: 6.0000 - val_tn: 73.0000 - val_tp: 54.0000 - val_precision: 0.9000 - val_recall: 0.9310
# Epoch 14/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1968 - accuracy: 0.9246 - fn: 16.0000 - fp: 15.0000 - tn: 223.0000 - tp: 157.0000 - precision: 0.9128 - recall: 0.9075 - val_loss: 0.1866 - val_accuracy: 0.9343 - val_fn: 5.0000 - val_fp: 4.0000 - val_tn: 75.0000 - val_tp: 53.0000 - val_precision: 0.9298 - val_recall: 0.9138
# Epoch 15/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.
0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 50.0000 - val_precision: 0.9434 - val_recall: 0.8621
# Epoch 181/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9538 - fn: 17.0000 - fp: 2.0000 - tn: 236.0000 - tp: 156.0000 - precision: 0.9873 - recall: 0.9017 - val_loss: 0.4376 - val_accuracy: 0.9489 - val_fn: 3.0000 - val_fp: 4.0000 - val_tn: 75.0000 - val_tp: 55.0000 - val_precision: 0.9322 - val_recall: 0.9483
# Epoch 182/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1416 - accuracy: 0.9416 - fn: 18.0000 - fp: 6.0000 - tn: 232.0000 - tp: 155.0000 - precision: 0.9627 - recall: 0.8960 - val_loss: 0.3948 - val_accuracy: 0.9489 - val_fn: 1.0000 - val_fp: 6.0000 - val_tn: 73.0000 - val_tp: 57.0000 - val_precision: 0.9048 - val_recall: 0.9828
# Epoch 183/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9367 - fn: 16.0000 - fp: 10.0000 - tn: 228.0000 - tp: 157.0000 - precision: 0.9401 - recall: 0.9075 - val_loss: 0.3834 - val_accuracy: 0.9343 - val_fn: 2.0000 - val_fp: 7.0000 - val_tn: 72.0000 - val_tp: 56.0000 - val_precision: 0.8889 - val_recall: 0.9655
# Epoch 184/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9440 - fn: 13.0000 - fp: 10.0000 - tn: 228.0000 - tp: 160.0000 - precision: 0.9412 - recall: 0.9249 - val_loss: 0.4165 - val_accuracy: 0.9416 - val_fn: 4.0000 - val_fp: 4.0000 - val_tn: 75.0000 - val_tp: 54.0000 - val_precision: 0.9310 - val_recall: 0.9310
# Epoch 185/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.9465 - fn: 13.0000 - fp: 9.0000 - tn: 229.0000 - tp: 160.0000 - precision: 0.9467 - recall: 0.9249 - val_loss: 0.4142 - val_accuracy: 0.9343 - val_fn: 5.0000 - val_fp: 4.0000 - val_tn: 75.0000 - val_tp: 53.0000 - val_precision: 0.9298 - val_recall: 0.9138
# Epoch 186/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.9513 - fn: 13.0000 - fp: 7.0000 - tn: 231.0000 - tp: 160.0000 - precision: 0.9581 - recall: 0.9249 - val_loss: 0.4780 - val_accuracy: 0.9416 - val_fn: 5.0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 53.0000 - val_precision: 0.9464 - val_recall: 0.9138
# Epoch 187/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9513 - fn: 15.0000 - fp: 5.0000 - tn: 233.0000 - tp: 158.0000 - precision: 0.9693 - recall: 0.9133 - val_loss: 0.3474 - val_accuracy: 0.9343 - val_fn: 6.0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 52.0000 - val_precision: 0.9455 - val_recall: 0.8966
# Epoch 188/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1629 - accuracy: 0.9416 - fn: 17.0000 - fp: 7.0000 - tn: 231.0000 - tp: 156.0000 - precision: 0.9571 - recall: 0.9017 - val_loss: 0.3369 - val_accuracy: 0.9416 - val_fn: 4.0000 - val_fp: 4.0000 - val_tn: 75.0000 - val_tp: 54.0000 - val_precision: 0.9310 - val_recall: 0.9310
# Epoch 189/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1245 - accuracy: 0.9513 - fn: 11.0000 - fp: 9.0000 - tn: 229.0000 - tp: 162.0000 - precision: 0.9474 - recall: 0.9364 - val_loss: 0.5515 - val_accuracy: 0.9416 - val_fn: 5.0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 53.0000 - val_precision: 0.9464 - val_recall: 0.9138
# Epoch 190/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 0.9513 - fn: 14.0000 - fp: 6.0000 - tn: 232.0000 - tp: 159.0000 - precision: 0.9636 - recall: 0.9191 - val_loss: 0.3102 - val_accuracy: 0.9635 - val_fn: 1.0000 - val_fp: 4.0000 - val_tn: 75.0000 - val_tp: 57.0000 - val_precision: 0.9344 - val_recall: 0.9828
# Epoch 191/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1595 - accuracy: 0.9319 - fn: 18.0000 - fp: 10.0000 - tn: 228.0000 - tp: 155.0000 - precision: 0.9394 - recall: 0.8960 - val_loss: 0.3169 - val_accuracy: 0.9343 - val_fn: 6.0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 52.0000 - val_precision: 0.9455 - val_recall: 0.8966
# Epoch 192/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1002 - accuracy: 0.9611 - fn: 12.0000 - fp: 4.0000 - tn: 234.0000 - tp: 161.0000 - precision: 0.9758 - recall: 0.9306 - val_loss: 0.4365 - val_accuracy: 0.9343 - val_fn: 4.0000 - val_fp: 5.0000 - val_tn: 74.0000 - val_tp: 54.0000 - val_precision: 0.9153 - val_recall: 0.9310
# Epoch 193/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.9586 - fn: 10.0000 - fp: 7.0000 - tn: 231.0000 - tp: 163.0000 - precision: 0.9588 - recall: 0.9422 - val_loss: 0.6517 - val_accuracy: 0.9051 - val_fn: 4.0000 - val_fp: 9.0000 - val_tn: 70.0000 - val_tp: 54.0000 - val_precision: 0.8571 - val_recall: 0.9310
# Epoch 194/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1216 - accuracy: 0.9440 - fn: 18.0000 - fp: 5.0000 - tn: 233.0000 - tp: 155.0000 - precision: 0.9688 - recall: 0.8960 - val_loss: 0.7583 - val_accuracy: 0.9343 - val_fn: 3.0000 - val_fp: 6.0000 - val_tn: 73.0000 - val_tp: 55.0000 - val_precision: 0.9016 - val_recall: 0.9483
# Epoch 195/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1470 - accuracy: 0.9513 - fn: 13.0000 - fp: 7.0000 - tn: 231.0000 - tp: 160.0000 - precision: 0.9581 - recall: 0.9249 - val_loss: 0.4511 - val_accuracy: 0.9416 - val_fn: 3.0000 - val_fp: 5.0000 - val_tn: 74.0000 - val_tp: 55.0000 - val_precision: 0.9167 - val_recall: 0.9483
# Epoch 196/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.0996 - accuracy: 0.9538 - fn: 9.0000 - fp: 10.0000 - tn: 228.0000 - tp: 164.0000 - precision: 0.9425 - recall: 0.9480 - val_loss: 0.4539 - val_accuracy: 0.9562 - val_fn: 3.0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 55.0000 - val_precision: 0.9483 - val_recall: 0.9483
# Epoch 197/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1001 - accuracy: 0.9538 - fn: 12.0000 - fp: 7.0000 - tn: 231.0000 - tp: 161.0000 - precision: 0.9583 - recall: 0.9306 - val_loss: 0.6083 - val_accuracy: 0.9489 - val_fn: 1.0000 - val_fp: 6.0000 - val_tn: 73.0000 - val_tp: 57.0000 - val_precision: 0.9048 - val_recall: 0.9828
# Epoch 198/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.9586 - fn: 10.0000 - fp: 7.0000 - tn: 231.0000 - tp: 163.0000 - precision: 0.9588 - recall: 0.9422 - val_loss: 0.5314 - val_accuracy: 0.9489 - val_fn: 2.0000 - val_fp: 5.0000 - val_tn: 74.0000 - val_tp: 56.0000 - val_precision: 0.9180 - val_recall: 0.9655
# Epoch 199/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1143 - accuracy: 0.9416 - fn: 14.0000 - fp: 10.0000 - tn: 228.0000 - tp: 159.0000 - precision: 0.9408 - recall: 0.9191 - val_loss: 0.4296 - val_accuracy: 0.9416 - val_fn: 5.0000 - val_fp: 3.0000 - val_tn: 76.0000 - val_tp: 53.0000 - val_precision: 0.9464 - val_recall: 0.9138
# Epoch 200/200
# 42/42 [==============================] - 0s 4ms/step - loss: 0.1605 - accuracy: 0.9319 - fn: 20.0000 - fp: 8.0000 - tn: 230.0000 - tp: 153.0000 - precision: 0.9503 - recall: 0.8844 - val_loss: 0.5055 - val_accuracy: 0.9343 - val_fn: 1.0000 - val_fp: 8.0000 - val_tn: 71.0000 - val_tp: 57.0000 - val_precision: 0.8769 - val_recall: 0.9828

# %%
# list all data in history
print(history.history.keys())
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'fn', 'fp', 'tn', 'tp', 'precision', 'recall', 'val_loss', 'val_accuracy', 'val_fn', 'val_fp', 'val_tn', 'val_tp', 'val_precision', 'val_recall'])

# %%
y_true, y_pred = y_test, model.predict_classes(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# WARNING:tensorflow:From <ipython-input-22-9f5e0e37f930>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Accuracy:  0.934
# Recall:  0.983
# Precision:  0.877
# ROC AUC:  0.941

# %% [markdown]
# ## Feature importance

# %%
X.columns
# Out:
# Index(['mu1', 'lam1', 'mu2', 'sigma', 'mu3', 'sigma3', 'w1', 'w2', 'w3',
#        'n_spikes'],
#       dtype='object')

# %%
result = permutation_importance(svm_model, X_train, y_train, 
                           n_repeats=30,
                           random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-48cba98593bc> in <module>
# ----> 1 result = permutation_importance(svm_model, X_train, y_train,
#       2                            n_repeats=30,
#       3                            random_state=0)
#
# NameError: name 'svm_model' is not defined

# %%
sorted_idx = result.importances_mean.argsort()

fig, ax = plt.subplots(figsize = (10,10))
ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=X.columns[sorted_idx])
ax.set_title("Permutation Importances (test set)")
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-155004c7c854> in <module>
# ----> 1 sorted_idx = result.importances_mean.argsort()
#       2
#       3 fig, ax = plt.subplots(figsize = (10,10))
#       4 ax.boxplot(result.importances[sorted_idx].T,
#       5            vert=False, labels=X.columns[sorted_idx])
#
# NameError: name 'result' is not defined

# %% [markdown]
# # Classification with Nets after KA stimulation

# %%
from scipy import stats

# %%
dataset_after = pd.read_csv('Data after PP/DataAfter')

# %%
dataset_after = dataset_after.drop(['Unnamed: 0'],axis=1)

# %%
print('Target LRRK2 vs Healthy\n',dataset_after['Target'].value_counts())
print('Stimulated LRRK2 vs Healthy\n',dataset_after['Stimulation'].value_counts())
# Out:
# Target LRRK2 vs Healthy
#  0.0    176
# 1.0    166
# Name: Target, dtype: int64
# Stimulated LRRK2 vs Healthy
#  1.0    177
# 0.0    165
# Name: Stimulation, dtype: int64

# %%
def plot_boxplot(target,column,dataset,dataset_after):
    x_list_param_boxplot=[]
    y_list_param_boxplot=[]


    y_list_param_boxplot.extend(dataset[dataset['Target']==target][column].values)
    len1 = dataset[dataset['Target']==target][column].values.shape[0]
    y_list_param_boxplot.extend(dataset_after[(dataset_after['Target']==target) &(dataset_after['Stimulation']==0)][column].values)
    len2 = dataset_after[(dataset_after['Target']==target) &(dataset_after['Stimulation']==0)][column].values.shape[0]
    y_list_param_boxplot.extend(dataset_after[(dataset_after['Target']==target) &(dataset_after['Stimulation']==1)][column].values)
    len3 = dataset_after[(dataset_after['Target']==target) &(dataset_after['Stimulation']==1)][column].values.shape[0]

    strs1 = ["Baseline" for x in range(len1)]
    strs2 = ["Control" for x in range(len2)]
    strs3 = ["Stimulated" for x in range(len3)]

    x_list_param_boxplot.extend(strs1)
    x_list_param_boxplot.extend(strs2)
    x_list_param_boxplot.extend(strs3)
    
    plt.figure(figsize=(5,5))
    
    if target==0:
        title = 'Healthy - '+column
    else:
        title = 'LRRK2 - '+column
    plt.title(title)
    sns.boxplot(x_list_param_boxplot,y_list_param_boxplot)
    
    #return y_list_param_boxplot
    stat,p_original=stats.shapiro(y_list_param_boxplot[:len1])
    stat,p=stats.shapiro(y_list_param_boxplot[len1:len1+len2])
    if (p>0.05) and (p_original>0.05):
        stat,t =stats.mannwhitneyu(y_list_param_boxplot[:len1],y_list_param_boxplot[len1:len1+len2],alternative='two-sided')
        print('Control: ',t)
    else:
        stat,t =stats.ttest_ind(y_list_param_boxplot[:len1],y_list_param_boxplot[len1:len1+len2])
        print('Control: ',t)
        
    stat,p=stats.shapiro(y_list_param_boxplot[len1+len2:])
    if (p>0.05) and (p_original>0.05):
        stat,t =stats.mannwhitneyu(y_list_param_boxplot[:len1],y_list_param_boxplot[len1+len2:],alternative='two-sided')
        print('Stimulation: ',t)
    else:
        stat,t =stats.ttest_ind(y_list_param_boxplot[:len1],y_list_param_boxplot[len1+len2:])
        print('Stimulation: ',t)

# %%
for col in dataset_after.columns.tolist():
    print(col)
    print('Healthy')
    t = plot_boxplot(0,col,dataset,dataset_after)
    print('LRRK2')
    t = plot_boxplot(1,col,dataset,dataset_after)
    print('\n\n')
# Out:
# mu1
# Healthy
# Control:  0.0033996867836613566
# Stimulation:  0.02082922589477501
# LRRK2
# Control:  0.4937893486786544
# Stimulation:  8.793783190091203e-05
#
#
#
# lam1
# Healthy
# Control:  0.005913487964413531
# Stimulation:  0.17824482367731684
# LRRK2
# Control:  0.9212421685898304
# Stimulation:  6.570341774232882e-06
#
#
#
# mu2
# Healthy
# Control:  0.0037174448055440974
# Stimulation:  0.09829923655899435
# LRRK2
# Control:  0.17523658903012715
# Stimulation:  0.29207628422747817
#
#
#
# sigma
# Healthy
# Control:  0.48332153887270424
# Stimulation:  0.06032951474395615
# LRRK2
# Control:  0.6189784559724119
# Stimulation:  0.03139484685495524
#
#
#
# mu3
# Healthy
# Control:  0.10031378990101998
# Stimulation:  0.04440028475895933
# LRRK2
# Control:  0.24592105820676097
# Stimulation:  3.198823998328054e-06
#
#
#
# sigma3
# Healthy
# Control:  0.14071142685502847
# Stimulation:  0.2704032340489211
# LRRK2
# Control:  0.846893240538684
# Stimulation:  2.7393039174885673e-05
#
#
#
# w1
# Healthy
# Control:  0.554023305698465
# Stimulation:  0.015817644418683427
# LRRK2
# Control:  0.00038554706556592267
# Stimulation:  0.03583895475420539
#
#
#
# w2
# Healthy
# Control:  0.5822476959696563
# Stimulation:  0.012486706857869616
# LRRK2
# Control:  0.003309947089524259
# Stimulation:  0.07192829214127314
#
#
#
# w3
# Healthy
# Control:  0.5605032003441632
# Stimulation:  0.04837238662730983
# LRRK2
# Control:  3.95166250642945e-05
# Stimulation:  0.018592692606678358
#
#
#
# n_spikes
# Healthy
# Control:  0.06029249922517693
# Stimulation:  0.4651571370030032
# LRRK2
# Control:  0.12015017893012689
# Stimulation:  7.163095426891214e-05
#
#
#
# Target
# Healthy
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Input data for shapiro has range zero. The results may not be accurate.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-cfa80ec0ce64> in <module>
#       2     print(col)
#       3     print('Healthy')
# ----> 4     t = plot_boxplot(0,col,dataset,dataset_after)
#       5     print('LRRK2')
#       6     t = plot_boxplot(1,col,dataset,dataset_after)
#
# <ipython-input-161-2c5820caa498> in plot_boxplot(target, column, dataset, dataset_after)
#      32     stat,p=stats.shapiro(y_list_param_boxplot[len1:len1+len2])
#      33     if (p>0.05) and (p_original>0.05):
# ---> 34         stat,t =stats.mannwhitneyu(y_list_param_boxplot[:len1],y_list_param_boxplot[len1:len1+len2],alternative='two-sided')
#      35         print('Control: ',t)
#      36     else:
#
# ~/anaconda3/envs/tesi_neuro/lib/python3.8/site-packages/scipy/stats/stats.py in mannwhitneyu(x, y, use_continuity, alternative)
#    7023     T = tiecorrect(ranked)
#    7024     if T == 0:
# -> 7025         raise ValueError('All numbers are identical in mannwhitneyu')
#    7026     sd = np.sqrt(T * n1 * n2 * (n1+n2+1) / 12.0)
#    7027
#
# ValueError: All numbers are identical in mannwhitneyu

# %% [markdown]
# # Unsupervised learning

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from sklearn import metrics

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
X = dataset_after.drop(['Target','Stimulation'],axis=1)

target = dataset_after['Target']
stim = dataset_after['Stimulation']

# %%
col = X.columns.tolist()
X = StandardScaler().fit_transform(X)


lut = dict(zip(stim.unique(), "rbg"))
row_colors_stim = stim.map(lut)
lut = dict(zip(target.unique(), "rbg"))
row_colors_target = target.map(lut)

row_colors=[row_colors_stim,row_colors_target]
X = pd.DataFrame(X,columns=col)
g = sns.clustermap(X,row_colors=row_colors,
                  method = 'ward',
                  metric='euclidean')

# %% [markdown]
# # Multilabel classification

# %%
dataset_after = pd.read_csv('Data after PP/DataAfter')
dataset_after = dataset_after.drop(['Unnamed: 0'],axis=1)

# %%
list_ml=[]
for i in dataset_after.index:
    if dataset_after.loc[i]['Target']==0 and dataset_after.loc[i]['Stimulation']==0:
        list_ml.append(0)
    elif dataset_after.loc[i]['Target']==1 and dataset_after.loc[i]['Stimulation']==0:
        list_ml.append(1)
    elif dataset_after.loc[i]['Target']==0 and dataset_after.loc[i]['Stimulation']==1:
        list_ml.append(2)
    else :
        list_ml.append(3)
        
        
## 0 ---> Healthy non stimulated
## 1 ---> LRRK2 non stimulated
## 2 ---> Healthy stimulated
## 3 ---> LRRK2 stimulated

# %%
dataset_after['MultiLabel Target']=list_ml

# %%
dataset_after['MultiLabel Target'].value_counts()
# Out:
# 2    100
# 1     89
# 3     77
# 0     76
# Name: MultiLabel Target, dtype: int64

# %%
X = dataset_after.drop(['Target','Stimulation','MultiLabel Target'],axis=1)
y= dataset_after['MultiLabel Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25,
                                                    stratify=y,
                                                    random_state=42)

# %% [markdown]
# ## Standardization

# %%
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Model Comparison

# %%
cv = StratifiedKFold(4)

# %% [markdown]
# ## 1) Decision Tree Classifier

# %%
print("Classification report on Test set\n")
gs = DecisionTreeClassifier(max_depth=7,random_state=12)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
# Out:
# Classification report on Test set
#
# Accuracy:  0.57
# Recall:  0.57
# Precision:  0.569

# %%
#print('ROC AUC: ',roc_auc)
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (10,7))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted',fontdict={'size':20})
plt.ylabel('True',fontdict={'size':20})
# Out:
# Text(66.5, 0.5, 'True')

# %% [markdown]
# ## 2) Logistic Regression

# %%
print("Classification report on Test set\n")
gs = LogisticRegression(penalty='l2',C=0.5,random_state=12)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
#print('ROC AUC: ',roc_auc)
cm=metrics.confusion_matrix(y_true,y_pred)
df_cm = pd.DataFrame(cm)
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4) # for label size
sns.heatmap(df_cm,annot=True)
# Out:
# Classification report on Test set
#
# Accuracy:  0.57
# Recall:  0.57
# Precision:  0.562

# %% [markdown]
# ## 3) Support Vector Machines

# %%
from hyperopt import hp

space = {}



#SVC
space['C']=hp.uniform('C',0.001,1000)
space['kernel']=hp.choice('kernel',['linear','rbf','sigmoid'])
space['gamma']=hp.choice('gamma',['scale','auto'])

# %%
from sklearn.model_selection import cross_val_score
def objective(params):
        ######################## hyper params ##############################

        params_SVC = {}

        params_SVC['C'] = params['C']
        params_SVC['kernel'] = params['kernel']
        params_SVC['gamma'] = params['gamma']
        

        ########################## Classifier definition ###################

        classifier = SVC(class_weight='balanced',random_state=12)
        classifier.set_params(**params_SVC)

        
        ######################### Model testing ################################

        shuffle = StratifiedKFold(n_splits=4, shuffle=True, random_state=12)
        
        

        score = cross_val_score(classifier, X_train, y_train, cv=shuffle, scoring='accuracy', n_jobs=-1)
        score = np.mean(score)
        
        

        return 1 - score

    ######################## Start optim ####################################



# The Trials object will store details of each iteration
trials = Trials()

    # Run the hyperparameter search using the tpe algorithm
best = fmin(objective,
                space,
                algo=tpe.suggest,
                max_evals=100,
                trials=trials)
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 15.12trial/s, best loss: 0.3828125]

# %%
cat = {}
cat['kernel'] = ['linear','rbf','sigmoid']
cat['gamma'] = ['scale','auto']

        
best_models = performance_visualizer(trials, 100, choice=True, **cat)

# %%
best_dict = best_models.to_dict(orient='records')[-1]

# %%
best_dict.pop('performance')
# Out:
# 0.6171875

# %%
best_dict
# Out:
# {'C': 71.53828029334753, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
print("Classification report on Test set\n")
gs = SVC(probability=True,random_state=12)
gs.set_params(**best_dict)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
#print('ROC AUC: ',roc_auc)
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (10,7))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted',fontdict={'size':20})
plt.ylabel('True',fontdict={'size':20})
# Out:
# Classification report on Test set
#
# Accuracy:  0.663
# Recall:  0.663
# Precision:  0.659
# Text(66.5, 0.5, 'True')

# %% [markdown]
# ## 4) K Nearest Neighbours

# %%
from hyperopt import hp

space = {}



#K Neighbours
space['n_neighbors']=hp.uniform('n_neighbors',2,100)
space['weights']=hp.choice('weights',['uniform','distance'])
space['algorithm']=hp.choice('algorithm',['auto','ball_tree','kd_tree','brute'])
space['p']=hp.choice('p',[1,2,3])

# %%
from sklearn.neighbors import KNeighborsClassifier

def objective(params):
        ######################## hyper params ##############################

        params_KN = {}

        params_KN['n_neighbors'] = int(params['n_neighbors'])
        params_KN['weights'] = params['weights']
        params_KN['algorithm'] = params['algorithm']
        params_KN['p'] = params['p']
        

        ########################## Classifier definition ###################

        classifier = KNeighborsClassifier(n_jobs=-1)
        classifier.set_params(**params_KN)

        
        ######################### Model testing ################################

        shuffle = StratifiedKFold(n_splits=4, shuffle=True, random_state=12)
        
        

        score = cross_val_score(classifier, X_train, y_train, cv=shuffle, scoring='accuracy', n_jobs=-1)
        score = np.mean(score)
        
        

        return 1 - score

    ######################## Start optim ####################################



# The Trials object will store details of each iteration
trials = Trials()

    # Run the hyperparameter search using the tpe algorithm
best = fmin(objective,
                space,
                algo=tpe.suggest,
                max_evals=100,
                trials=trials)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 49.79trial/s, best loss: 0.4140625]

# %%
cat = {}
cat['weights'] = ['uniform','distance']
cat['algorithm'] = ['auto','ball_tree','kd_tree','brute']
cat['p'] = [1,2,3]
        
best_models = performance_visualizer(trials, 100, choice=True, **cat)

# %%
best_models.to_dict(orient='records')[-1]
# Out:
# {'algorithm': 'ball_tree',
#  'n_neighbors': 11.552656791395938,
#  'p': 3,
#  'weights': 'distance',
#  'performance': 0.5859375}

# %%
best_dict = best_models.to_dict(orient='records')[-1]

# %%
best_dict.pop('performance')
# Out:
# 0.5859375

# %%
best_dict['n_neighbors']=int(best_dict['n_neighbors'])

# %%
print("Classification report on Test set\n")
gs = KNeighborsClassifier()
gs.set_params(**best_dict)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
#print('ROC AUC: ',roc_auc)
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (10,7))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted Label',fontdict={'size':20})
plt.ylabel('True Label',fontdict={'size':20})
# Out:
# Classification report on Test set
#
# Accuracy:  0.651
# Recall:  0.651
# Precision:  0.659
# Text(66.5, 0.5, 'True')

# %% [markdown]
# ## 5) Random Forest

# %%
from hyperopt import hp

space = {}


#RF
space['n_estimators'] = hp.choice('n_estimators', np.arange(50, 300,1, dtype=int))
space['max_samples'] = hp.uniform('max_samples',0.4,1)
space['max_samples'] = hp.uniform('max_samples',0.4,1)
space['max_features'] = hp.uniform('max_features',0.4,1)
space['criterion'] = hp.choice('criterion',['gini','entropy'])
space['max_depth'] = scope.intero(hp.quniform('max_depth',1,10,1))
space['ccp_alpha']=hp.uniform('ccp_alpha',0,0.01)
space['bootstrap']=hp.choice('bootstrap',[False,True])
space['min_samples_leaf']=scope.intero(hp.quniform('min_samples_leaf',1,5,1))
space['min_samples_split']=scope.intero(hp.quniform('min_samples_split',2,10,1))

# %%
from sklearn.ensemble import RandomForestClassifier

def objective(params):
        ######################## hyper params ##############################

        params_RF = {}
        
        params_RF['n_estimators'] = params['n_estimators']
        params_RF['max_samples'] = params['max_samples']
        params_RF['max_features'] = params['max_features']
        params_RF['criterion'] = params['criterion']
        params_RF['max_depth'] = params['max_depth']
        params_RF['ccp_alpha'] = params['ccp_alpha']
        params_RF['bootstrap'] = params['bootstrap']
        params_RF['min_samples_leaf'] = params['min_samples_leaf']
        params_RF['min_samples_split'] = params['min_samples_split']
        

        ########################## Classifier definition ###################

        classifier = RandomForestClassifier(n_jobs=-1)
        classifier.set_params(**params_RF)

        
        ######################### Model testing ################################

        shuffle = StratifiedKFold(n_splits=4, shuffle=True, random_state=12)
        
        

        score = cross_val_score(classifier, X_train, y_train, cv=shuffle, scoring='accuracy', n_jobs=-1)
        score = np.mean(score)
        
        

        return 1 - score

    ######################## Start optim ####################################



# The Trials object will store details of each iteration
trials = Trials()

    # Run the hyperparameter search using the tpe algorithm
best = fmin(objective,
                space,
                algo=tpe.suggest,
                max_evals=100,
                trials=trials)
# Out:
# 100%|██████████| 100/100 [00:31<00:00,  3.16trial/s, best loss: 0.37890625]

# %%
cat = {}
cat['n_estimators'] = np.arange(50, 150, dtype=int)
cat['bootstrap'] = [False,True]
cat['criterion'] = ['gini','entropy']
best_models = performance_visualizer(trials, 100, choice=True, **cat)

# %%
best_models.to_dict(orient='records')[-1]
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.009140650396046883,
#  'criterion': 'entropy',
#  'max_depth': 8.0,
#  'max_features': 0.5681956208176746,
#  'max_samples': 0.6801865304209019,
#  'min_samples_leaf': 3.0,
#  'min_samples_split': 6.0,
#  'n_estimators': 141,
#  'performance': 0.62109375}

# %%
best_dict = best_models.to_dict(orient='records')[-1]

# %%
best_dict.pop('performance')
# Out:
# 0.62109375

# %%
best_dict['min_samples_leaf']=int(best_dict['min_samples_leaf'])
best_dict['min_samples_split']=int(best_dict['min_samples_split'])

# %%
print("Classification report on Test set\n")
gs = RandomForestClassifier()
gs.set_params(**best_dict)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
#print('ROC AUC: ',roc_auc)
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (10,7))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted Label',fontdict={'size':20})
plt.ylabel('True Label',fontdict={'size':20})
# Out:
# Classification report on Test set
#
# Accuracy:  0.709
# Recall:  0.709
# Precision:  0.725
# Text(66.5, 0.5, 'True Label')

# %% [markdown]
# # Binary classification model on new test set

# %%
dataset_after = pd.read_csv('Data after PP/DataAfter')
dataset_after = dataset_after.drop(['Unnamed: 0'],axis=1)

# %%
list_ml=[]
for i in dataset_after.index:
    if dataset_after.loc[i]['Target']==0 and dataset_after.loc[i]['Stimulation']==0:
        list_ml.append(0)
    elif dataset_after.loc[i]['Target']==1 and dataset_after.loc[i]['Stimulation']==0:
        list_ml.append(1)
    elif dataset_after.loc[i]['Target']==0 and dataset_after.loc[i]['Stimulation']==1:
        list_ml.append(2)
    else :
        list_ml.append(3)

# %%
dataset_after['MultiLabel Target']=list_ml

# %%
dataset_after['MultiLabel Target'].value_counts()
# Out:
# 0    100
# 3     89
# 1     77
# 2     76
# Name: MultiLabel Target, dtype: int64

# %%
dataset_after=dataset_after.drop(['Target','Stimulation'],axis=1)
healthy_stim = dataset_after[dataset_after['MultiLabel Target']==0].drop(['MultiLabel Target'],axis=1)
lrrk2_stim = dataset_after[dataset_after['MultiLabel Target']==1].drop(['MultiLabel Target'],axis=1)
healthy_nostim = dataset_after[dataset_after['MultiLabel Target']==2].drop(['MultiLabel Target'],axis=1)
lrrk2_nostim = dataset_after[dataset_after['MultiLabel Target']==0].drop(['MultiLabel Target'],axis=1)

# %%
dataset = pd.read_csv('Data after PP/Data')

# %%
dataset = dataset.drop(['Unnamed: 0'],axis=1)

# %%
dataset
# Out:
#           mu1      lam1           mu2     sigma       mu3    sigma3        w1  \
# 0    0.099999  0.010000  1.376800e-01  0.069408  0.368091  0.172628  0.286221
# 1    0.019293  0.019831  6.633874e-02  0.000100  0.100001  0.000520  1.000000
# 2    0.043575  0.029764  1.779872e-01  0.000100  0.100064  0.000260  1.000000
# 3    0.024164  0.022119  6.418069e-02  0.000100  0.100010  0.000718  1.000000
# 4    0.048184  0.030814  4.696582e-03  0.000100  0.100139  0.000218  1.000000
# ..        ...       ...           ...       ...       ...       ...       ...
# 543  0.100000  0.011880  1.038845e-01  0.058294  0.483309  0.271518  0.332834
# 544  0.018542  0.018771  1.807094e-01  0.000100  0.100000  0.000106  1.000000
# 545  0.099969  0.039687  9.343772e-02  0.040354  0.267501  0.112234  0.630343
# 546  0.056240  0.031443  1.643654e-07  0.000100  0.100001  0.000100  1.000000
# 547  0.100000  0.040000  1.008357e-01  0.044780  0.403570  0.174828  0.774085
#
#                w2            w3  n_spikes  Target
# 0    4.179009e-01  2.958779e-01    1015.0     0.0
# 1    1.192093e-07  1.421085e-14   10364.0     0.0
# 2    1.192093e-07  1.421085e-14    4589.0     0.0
# 3    1.192093e-07  1.421085e-14    8274.0     0.0
# 4    1.192093e-07  1.421085e-14    4151.0     0.0
# ..            ...           ...       ...     ...
# 543  4.549999e-01  2.121657e-01    1029.0     1.0
# 544  1.192093e-07  1.421085e-14   10784.0     1.0
# 545  2.080073e-01  1.616492e-01    1523.0     1.0
# 546  1.192093e-07  1.421085e-14    3555.0     1.0
# 547  1.422010e-01  8.371432e-02    1475.0     1.0
#
# [548 rows x 11 columns]

# %%
dataset['Target'].value_counts()
# Out:
# 0.0    317
# 1.0    231
# Name: Target, dtype: int64

# %% [markdown]
# ## Train test split

# %%
X = dataset.drop(['Target'],axis=1)
y= dataset['Target']
scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# # Train model on baseline

# %%
params = {'C':np.logspace(-3,3,50),'kernel':['linear','rbf']}

clf = SVC(random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)

gs=gs.fit(X,y)

# %%
healthy_stim = scaler.transform(healthy_stim)
healthy_nostim = scaler.transform(healthy_nostim)
lrrk2_stim = scaler.transform(lrrk2_stim)
lrrk2_nostim = scaler.transform(lrrk2_nostim)

# %%
params = gs.best_params_
clf = SVC(**params,random_state=12)
clf.fit(X,y)
# Out:
# SVC(C=6.25055192527397, break_ties=False, cache_size=200, class_weight=None,
#     coef0=0.0, decision_function_shape='ovr', degree=3, gamma='scale',
#     kernel='rbf', max_iter=-1, probability=False, random_state=12,
#     shrinking=True, tol=0.001, verbose=False)

# %%
pred_healthy_stim = clf.predict(healthy_stim)
pred_healthy_nostim = clf.predict(healthy_nostim)
pred_lrrk2_stim = clf.predict(lrrk2_stim)
pred_lrrk2_nostim = clf.predict(lrrk2_nostim)

# %%
pred_healthy_stim.sum()
# Out:
# 0.0

# %%
print('Healthy stimulated: ',pred_healthy_stim.sum()/pred_healthy_stim.shape[0])
print('Healthy non stimulated: ',pred_healthy_nostim.sum()/pred_healthy_nostim.shape[0])
print('LRRK2 stimulated: ',pred_lrrk2_stim.sum()/pred_lrrk2_stim.shape[0])
print('LRRK2 non stimulated: ',pred_lrrk2_nostim.sum()/pred_lrrk2_nostim.shape[0])
# Out:
# Healthy stimulated:  0.0
# Healthy non stimulated:  0.23684210526315788
# LRRK2 stimulated:  0.8441558441558441
# LRRK2 non stimulated:  0.0
